# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Attrition_dataset.csv')
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df.head(5)   #top 5 rows
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.head(3)   #top 3 rows
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# ...

# %%
df.tail(5)  #last 5 rows
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %%
df.tail(3)  #bottom 3 elements
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name job_title  store_name gender_short gender_full  \
# 49650  Customer Service   Cashier          39            F      Female
# 49651  Customer Service   Cashier          16            F      Female
# 49652  Customer Service   Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# ...

# %%
df.columns  #name of columns n data set
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# EmployeeID             0
# recorddate_key         0
# birthdate_key          0
# orighiredate_key       0
# terminationdate_key    0
# age                    0
# length_of_service      0
# city_name              0
# department_name        0
# job_title              0
# store_name             0
# gender_short           0
# gender_full            0
# termreason_desc        0
# termtype_desc          0
# STATUS_YEAR            0
# STATUS                 0
# BUSINESS_UNIT          0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49648    False
# 49649    False
# 49650    False
# 49651    False
# 49652    False
# Length: 49653, dtype: bool

# %%
df.duplicated('EmployeeID')
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 49648     True
# 49649    False
# 49650     True
# 49651     True
# 49652     True
# Length: 49653, dtype: bool

# %%
df.EmployeeID.duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 49648     True
# 49649    False
# 49650     True
# 49651     True
# 49652     True
# Name: EmployeeID, Length: 49653, dtype: bool

# %%
df['EmployeeID'].duplicated().any()
# Out:
# np.True_

# %%
# df.EmployeeID=df.EmployeeID.drop_duplicates()  
# df

# %%
df.EmployeeID=df.EmployeeID.drop_duplicates(keep='last') 
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0             NaN  12/31/2006 0:00      1/3/1954        8/28/1989
# 1             NaN  12/31/2007 0:00      1/3/1954        8/28/1989
# 2             NaN  12/31/2008 0:00      1/3/1954        8/28/1989
# 3             NaN  12/31/2009 0:00      1/3/1954        8/28/1989
# 4             NaN  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df=df.dropna()

df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 9          1318.0  12/31/2015 0:00      1/3/1954        8/28/1989
# 19         1319.0  12/31/2015 0:00      1/3/1957        8/28/1989
# 29         1320.0  12/31/2015 0:00      1/2/1955        8/28/1989
# 39         1321.0  12/31/2015 0:00      1/2/1959        8/28/1989
# 49         1322.0  12/31/2015 0:00      1/9/1958        8/31/1989
# ...           ...              ...           ...              ...
# 49648      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 9                1/1/1900   61                 26    Vancouver
# ...

# %%
df.reset_index()  #two index we get
# Out:
#       index  EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0         9      1318.0  12/31/2015 0:00      1/3/1954        8/28/1989
# 1        19      1319.0  12/31/2015 0:00      1/3/1957        8/28/1989
# 2        29      1320.0  12/31/2015 0:00      1/2/1955        8/28/1989
# 3        39      1321.0  12/31/2015 0:00      1/2/1959        8/28/1989
# 4        49      1322.0  12/31/2015 0:00      1/9/1958        8/31/1989
# ...     ...         ...              ...           ...              ...
# 6279  49648      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 6280  49649      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 6281  49650      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 6282  49651      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 6283  49652      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#      terminationdate_key  age  length_of_service    city_name  \
# ...

# %%
df=df.reset_index(drop='True')
df
# Out:
#       EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0         1318.0  12/31/2015 0:00      1/3/1954        8/28/1989
# 1         1319.0  12/31/2015 0:00      1/3/1957        8/28/1989
# 2         1320.0  12/31/2015 0:00      1/2/1955        8/28/1989
# 3         1321.0  12/31/2015 0:00      1/2/1959        8/28/1989
# 4         1322.0  12/31/2015 0:00      1/9/1958        8/31/1989
# ...          ...              ...           ...              ...
# 6279      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 6280      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 6281      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 6282      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 6283      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#      terminationdate_key  age  length_of_service    city_name  \
# 0               1/1/1900   61                 26    Vancouver
# ...

# %%
pd.to_datetime(df.recorddate_key)
# Out:
# 0      2015-12-31
# 1      2015-12-31
# 2      2015-12-31
# 3      2015-12-31
# 4      2015-12-31
#           ...
# 6279   2015-12-01
# 6280   2013-08-01
# 6281   2015-12-01
# 6282   2013-12-01
# 6283   2014-12-01
# Name: recorddate_key, Length: 6284, dtype: datetime64[ns]

# %%
for col in ['recorddate_key', 'birthdate_key', 'orighiredate_key',
       'terminationdate_key']:
    df[col]=pd.to_datetime(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           6284 non-null   float64
#  1   recorddate_key       6284 non-null   datetime64[ns]
#  2   birthdate_key        6284 non-null   datetime64[ns]
#  3   orighiredate_key     6284 non-null   datetime64[ns]
#  4   terminationdate_key  6284 non-null   datetime64[ns]
#  5   age                  6284 non-null   int64
#  6   length_of_service    6284 non-null   int64
#  7   city_name            6284 non-null   object
#  8   department_name      6284 non-null   object
#  9   job_title            6284 non-null   object
#  10  store_name           6284 non-null   int64
#  11  gender_short         6284 non-null   object
#  12  gender_full          6284 non-null   object
#  13  termreason_desc      6284 non-null   object
# ...

# %%
d={'EmployeeID':'ID','recorddate_key':'Record_data'}

df=df.rename(columns=d)
# df=df.rename(d,axis=1)       #axis=0 for row rename
df
# Out:
#           ID Record_data birthdate_key orighiredate_key terminationdate_key  \
# 0     1318.0  2015-12-31    1954-01-03       1989-08-28          1900-01-01
# 1     1319.0  2015-12-31    1957-01-03       1989-08-28          1900-01-01
# 2     1320.0  2015-12-31    1955-01-02       1989-08-28          1900-01-01
# 3     1321.0  2015-12-31    1959-01-02       1989-08-28          1900-01-01
# 4     1322.0  2015-12-31    1958-01-09       1989-08-31          1900-01-01
# ...      ...         ...           ...              ...                 ...
# 6279  8258.0  2015-12-01    1994-05-28       2013-08-19          2015-12-30
# 6280  8264.0  2013-08-01    1994-06-13       2013-08-27          2013-08-30
# 6281  8279.0  2015-12-01    1994-07-18       2013-09-15          2015-12-30
# 6282  8296.0  2013-12-01    1994-09-02       2013-10-09          2013-12-31
# 6283  8321.0  2014-12-01    1994-11-28       2013-11-24          2014-12-30
#
# ...

# %%
# df.drop(['store_name'],axis=1)
df=df.drop(columns='store_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6284 non-null   float64
#  1   Record_data          6284 non-null   datetime64[ns]
#  2   birthdate_key        6284 non-null   datetime64[ns]
#  3   orighiredate_key     6284 non-null   datetime64[ns]
#  4   terminationdate_key  6284 non-null   datetime64[ns]
#  5   age                  6284 non-null   int64
#  6   length_of_service    6284 non-null   int64
#  7   city_name            6284 non-null   object
#  8   department_name      6284 non-null   object
#  9   job_title            6284 non-null   object
#  10  gender_short         6284 non-null   object
#  11  gender_full          6284 non-null   object
#  12  termreason_desc      6284 non-null   object
#  13  termtype_desc        6284 non-null   object
# ...

# %%
df=df.astype({'ID':int})

# %%
d={'birthdate_key':'DOB','orighiredate_key':'hire_date','terminationdate_key':'term_date','length_of_service':'experence','city_name':'city','department_name':'dname','job_title':'job','gender_full':'Gender','termreason_desc':'term_reason','STATUS_YEAR':'STATUS_YEAR','STATUS':'status','BUSSNESS_UNT':'busness_unt'}
df=df.rename(columns=d)
df
# Out:
#         ID Record_data        DOB  hire_date  term_date  age  experence  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61         26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58         26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60         26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56         26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57         26
# ...    ...         ...        ...        ...        ...  ...        ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21          2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19          0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21          2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19          0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20          1
#
#              city             dname                 job gender_short  Gender  \
# ...

# %%
df=df.drop(columns=['gender_short'])
df
# Out:
#         ID Record_data        DOB  hire_date  term_date  age  experence  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61         26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58         26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60         26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56         26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57         26
# ...    ...         ...        ...        ...        ...  ...        ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21          2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19          0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21          2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19          0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20          1
#
#              city             dname                 job  Gender  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Record_data', 'DOB', 'hire_date', 'term_date', 'age',
#        'experence', 'city', 'dname', 'job', 'Gender', 'term_reason',
#        'termtype_desc', 'STATUS_YEAR', 'status', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
for col in ['status', 'BUSINESS_UNIT']:
    df[col]=df[col].str.title()

# %%
r_date=df.query("status=='Active'")['Record_data']
df.loc[df['status']=='Active','term_date']=r_date
df
# Out:
#         ID Record_data        DOB  hire_date  term_date  age  experence  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61         26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58         26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60         26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56         26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57         26
# ...    ...         ...        ...        ...        ...  ...        ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21          2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19          0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21          2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19          0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20          1
#
#              city             dname                 job  Gender  \
# ...

# %%
df['exp_level']=pd.cut(df['experence'],bins=[0,2,10,26],labels=['junior','Mid-senior','senior'],include_lowest=True)
df
# Out:
#         ID Record_data        DOB  hire_date  term_date  age  experence  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61         26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58         26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60         26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56         26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57         26
# ...    ...         ...        ...        ...        ...  ...        ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21          2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19          0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21          2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19          0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20          1
#
#              city             dname                 job  Gender  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Record_data', 'DOB', 'hire_date', 'term_date', 'age',
#        'experence', 'city', 'dname', 'job', 'Gender', 'term_reason',
#        'termtype_desc', 'STATUS_YEAR', 'status', 'BUSINESS_UNIT', 'exp_level'],
#       dtype='object')

# %%
lst=['ID','DOB','age','Gender','hire_date','dname','job','city','experence','exp_level','BUSINESS_UNIT','status','term_date','termtype_desc','term_reason','Record_data','STATUS_YEAR']
df=df[lst]

# %%
df
# Out:
#         ID        DOB  age  Gender  hire_date             dname  \
# 0     1318 1954-01-03   61    Male 1989-08-28         Executive
# 1     1319 1957-01-03   58  Female 1989-08-28         Executive
# 2     1320 1955-01-02   60  Female 1989-08-28         Executive
# 3     1321 1959-01-02   56    Male 1989-08-28         Executive
# 4     1322 1958-01-09   57    Male 1989-08-31         Executive
# ...    ...        ...  ...     ...        ...               ...
# 6279  8258 1994-05-28   21    Male 2013-08-19             Dairy
# 6280  8264 1994-06-13   19  Female 2013-08-27  Customer Service
# 6281  8279 1994-07-18   21  Female 2013-09-15  Customer Service
# 6282  8296 1994-09-02   19  Female 2013-10-09  Customer Service
# 6283  8321 1994-11-28   20  Female 2013-11-24  Customer Service
#
#                      job         city  experence exp_level BUSINESS_UNIT  \
# 0                    CEO    Vancouver         26    senior    Headoffice
# ...

# %%
df['dname'].unique()
# Out:
# array(['Executive', 'Store Management', 'Meats', 'Recruitment',
#        'Customer Service', 'Produce', 'Bakery', 'Dairy',
#        'Processed Foods', 'Training', 'Labor Relations', 'HR Technology',
#        'Employee Records', 'Compensation', 'Legal',
#        'Accounts Receiveable', 'Information Technology',
#        'Accounts Payable', 'Audit', 'Accounting', 'Investment'],
#       dtype=object)

# %%
df['job'].unique()
# Out:
# array(['CEO', 'VP Stores', 'Legal Counsel', 'VP Human Resources',
#        'VP Finance', 'Exec Assistant, VP Stores',
#        'Exec Assistant, Legal Counsel', 'CHief Information Officer',
#        'Store Manager', 'Meats Manager',
#        'Exec Assistant, Human Resources', 'Exec Assistant, Finance',
#        'Director, Recruitment', 'Meat Cutter', 'Customer Service Manager',
#        'Produce Manager', 'Bakery Manager', 'Dairy Person',
#        'Processed Foods Manager', 'Produce Clerk', 'Baker',
#        'Shelf Stocker', 'Cashier', 'Director, Training',
#        'Director, Labor Relations', 'Director, HR Technology',
#        'Director, Employee Records', 'Director, Compensation',
#        'Corporate Lawyer', 'Director, Accounts Receivable',
#        'Systems Analyst', 'Director, Accounts Payable', 'Director, Audit',
#        'Director, Accounting', 'Director, Investments', 'Recruiter',
#        'Trainer', 'Labor Relations Analyst', 'Dairy Manager',
# ...

# %%
# df['job'].str.split(',').str[0]

# %%
def f1(d):
    return d['job'].split(",")[0]

df['job']=df.apply(f1,axis=1)
df
# Out:
#         ID        DOB  age  Gender  hire_date             dname  \
# 0     1318 1954-01-03   61    Male 1989-08-28         Executive
# 1     1319 1957-01-03   58  Female 1989-08-28         Executive
# 2     1320 1955-01-02   60  Female 1989-08-28         Executive
# 3     1321 1959-01-02   56    Male 1989-08-28         Executive
# 4     1322 1958-01-09   57    Male 1989-08-31         Executive
# ...    ...        ...  ...     ...        ...               ...
# 6279  8258 1994-05-28   21    Male 2013-08-19             Dairy
# 6280  8264 1994-06-13   19  Female 2013-08-27  Customer Service
# 6281  8279 1994-07-18   21  Female 2013-09-15  Customer Service
# 6282  8296 1994-09-02   19  Female 2013-10-09  Customer Service
# 6283  8321 1994-11-28   20  Female 2013-11-24  Customer Service
#
#                      job         city  experence exp_level BUSINESS_UNIT  \
# 0                    CEO    Vancouver         26    senior    Headoffice
# ...

# %%
df=df.rename({'termtype_desc':'termtype'})

# %% [markdown]
# Analysis

# %% [markdown]
# Find the total number of employees

# %%
df['ID'].count()
# len(df)
# df.shape[0]    #df.shape it wll return the tupple
# Out:
# np.int64(6284)

# %% [markdown]
# Find the number of unique values in term_reason

# %%
df['term_reason'].nunique()
# Out:
# 4

# %% [markdown]
# Get the unique values in term_reason

# %%
df['term_reason'].unique()
# Out:
# array(['Not Applicable', 'Retirement', 'Resignaton', 'Layoff'],
#       dtype=object)

# %% [markdown]
# find the number of unique values in gender job,dname,city,bussiness_unit

# %%
df[['job','Gender','dname','city','BUSINESS_UNIT']].nunique()
# Out:
# job              34
# Gender            2
# dname            21
# city             40
# BUSINESS_UNIT     2
# dtype: int64

# %% [markdown]
# give details present [0,25,700,500]

# %%
df.loc[[0,25,700,500]]
# Out:
#        ID        DOB  age  Gender  hire_date      dname           job  \
# 0    1318 1954-01-03   61    Male 1989-08-28  Executive           CEO
# 25   1721 1951-02-23   64    Male 1990-10-15      Meats   Meat Cutter
# 700  2857 1957-05-30   58  Female 1994-02-04     Bakery         Baker
# 500  2530 1955-10-21   60  Female 1993-03-31      Dairy  Dairy Person
#
#           city  experence exp_level BUSINESS_UNIT  status  term_date  \
# 0    Vancouver         26    senior    Headoffice  Active 2015-12-31
# 25   Cranbrook         25    senior        Stores  Active 2015-12-31
# 700    Burnaby         21    senior        Stores  Active 2015-12-31
# 500  Vancouver         22    senior        Stores  Active 2015-12-31
#
#       termtype_desc     term_reason Record_data  STATUS_YEAR
# 0    Not Applicable  Not Applicable  2015-12-31         2015
# 25   Not Applicable  Not Applicable  2015-12-31         2015
# 700  Not Applicable  Not Applicable  2015-12-31         2015
# ...

# %%
df.loc[[0,25,700,500],'job']
# Out:
# 0               CEO
# 25      Meat Cutter
# 700           Baker
# 500    Dairy Person
# Name: job, dtype: object

# %% [markdown]
# get job of 0,25,700,500 in ascending order

# %%
df.loc[[0,25,700,500],'job'].sort_index()      #alphabetic order ascendng order
# Out:
# 0               CEO
# 25      Meat Cutter
# 500    Dairy Person
# 700           Baker
# Name: job, dtype: object

# %% [markdown]
# get job of 0,25,700,500 in descending order

# %%
df.loc[[0,25,700,500],'job'].sort_values(ascending=False)
# Out:
# 25      Meat Cutter
# 500    Dairy Person
# 0               CEO
# 700           Baker
# Name: job, dtype: object

# %% [markdown]
# get the retirement employee job and experiance

# %%
df.term_reason.unique()
# Out:
# array(['Not Applicable', 'Retirement', 'Resignaton', 'Layoff'],
#       dtype=object)

# %%
# df.loc[df['term_reason']=='Retirement',['job','experence']]

df.query("term_reason=='Retirement'")[['job','experence']]
# Out:
#                 job  experence
# 4799       Director         19
# 4800  Store Manager         24
# 4801  Store Manager         19
# 4802       Director         19
# 4803  Store Manager         24
# ...             ...        ...
# 5819  Produce Clerk          8
# 5820  Produce Clerk          8
# 5821  Produce Clerk          8
# 5822          Baker         13
# 5824    Meat Cutter          8
#
# [885 rows x 2 columns]

# %% [markdown]
# get the retirement empoyee job and expiriance and sort it according to desc order of expiriance

# %%
# df.query("term_reason=='Retirement'")[['job','experence']].sort_values(by='experence',ascending=False)

df.loc[df['term_reason']=='Retirement',['job','experence']].sort_values(by='experence',ascending=False)
# Out:
#                            job  experence
# 4988  Customer Service Manager         25
# 5020              Dairy Person         25
# 4965          Accounting Clerk         25
# 5019             Meats Manager         25
# 5018   Processed Foods Manager         25
# ...                        ...        ...
# 5781             Produce Clerk          8
# 5784               Meat Cutter          8
# 5785             Produce Clerk          8
# 5787                     Baker          8
# 5824               Meat Cutter          8
#
# [885 rows x 2 columns]

# %% [markdown]
# get the retired male employee details

# %%
df.query("term_reason=='Retirement' & Gender=='Male'")
# Out:
#         ID        DOB  age Gender  hire_date             dname            job  \
# 4799  1338 1949-02-16   60   Male 1989-09-20          Training       Director
# 4801  1340 1949-02-19   60   Male 1989-09-22  Store Management  Store Manager
# 4802  1341 1949-02-21   60   Male 1989-09-23   Labor Relations       Director
# 4806  1347 1949-03-04   60   Male 1989-09-29             Meats  Meats Manager
# 4807  1351 1949-03-09   60   Male 1989-10-02      Compensation       Director
# ...    ...        ...  ...    ...        ...               ...            ...
# 5813  5084 1948-12-02   60   Male 2000-06-08             Meats    Meat Cutter
# 5819  5098 1948-12-20   60   Male 2000-06-26           Produce  Produce Clerk
# 5820  5099 1948-12-21   60   Male 2000-06-27           Produce  Produce Clerk
# 5821  5104 1948-12-23   60   Male 2000-06-29           Produce  Produce Clerk
# 5824  5112 1948-12-30   60   Male 2000-07-06             Meats    Meat Cutter
#
# ...

# %% [markdown]
# get the average age

# %%
df['age'].agg({'age':'mean'})
# Out:
# age    44.742998
# Name: age, dtype: float64

# %% [markdown]
# get the highest and lowest expiriance

# %%
print(df['experence'].max())
print(df.experence.min())
# Out:
# 26
# 0

# %%
df.agg({'experence':['max','min']})
# Out:
#      experence
# max         26
# min          0

# %% [markdown]
# get the no of employees in each term_type

# %%
g=df.groupby('termtype_desc')
# g['termtype_desc'].count()

df.groupby("termtype_desc").count()   #values in ascending order
#grouped col['termtype_desc'] will become index
#aggregated_valuesm will be column
# Out:
#                   ID   DOB   age  Gender  hire_date  dname   job  city  \
# termtype_desc
# Involuntary      215   215   215     215        215    215   215   215
# Not Applicable  4799  4799  4799    4799       4799   4799  4799  4799
# Voluntary       1270  1270  1270    1270       1270   1270  1270  1270
#
#                 experence  exp_level  BUSINESS_UNIT  status  term_date  \
# termtype_desc
# Involuntary           215        215            215     215        215
# Not Applicable       4799       4799           4799    4799       4799
# Voluntary            1270       1270           1270    1270       1270
#
#                 term_reason  Record_data  STATUS_YEAR
# termtype_desc
# Involuntary             215          215          215
# Not Applicable         4799         4799         4799
# Voluntary              1270         1270         1270

# %%
g.agg({'termtype_desc':'count'})
# Out:
#                 termtype_desc
# termtype_desc
# Involuntary               215
# Not Applicable           4799
# Voluntary                1270

# %%
df['termtype_desc'].value_counts()             #values in descending order 

#values_count(group by and )
# Out:
# termtype_desc
# Not Applicable    4799
# Voluntary         1270
# Involuntary        215
# Name: count, dtype: int64

# %% [markdown]
# get the least emp_count in each term_type

# %%
df['termtype_desc'].value_counts().min()
# Out:
# np.int64(215)

# %% [markdown]
# get the term_type in which least emp are present

# %%
df.groupby('termtype_desc').idxmin() #idx-index
# Out:
#                   ID   DOB   age  Gender  hire_date  dname   job  city  \
# termtype_desc
# Involuntary     4933  4933  6275    4933       4933   4933  4933  5837
# Not Applicable     0    14  4683       1          0     23   297    50
# Voluntary       4799  5054  6267    4800       4799   4822  4951  4995
#
#                 experence  exp_level  BUSINESS_UNIT  status  term_date  \
# termtype_desc
# Involuntary          6234       6198           4933    4933       4933
# Not Applicable       4631       4631              0       0          0
# Voluntary            5917       5899           4799    4799       5435
#
#                 term_reason  Record_data  STATUS_YEAR
# termtype_desc
# Involuntary            4933         4933         4933
# Not Applicable            0            0            0
# Voluntary              4817         5054         5046

# %% [markdown]
# get the term_type in which highest emp are present

# %%
df.groupby('termtype_desc').idxmax()
# Out:
#                   ID   DOB   age  Gender  hire_date  dname   job  city  \
# termtype_desc
# Involuntary     6283  6283  4933    4978       6283   4978  4978  5041
# Not Applicable  4798  4798    14       0       4798      8     1   124
# Voluntary       6282  6282  4800    4799       6282   4799  4844  4895
#
#                 experence  exp_level  BUSINESS_UNIT  status  term_date  \
# termtype_desc
# Involuntary          5024       4933           4933    4933       5024
# Not Applicable          0          0              8       0          0
# Voluntary            4843       4799           4800    4799       4981
#
#                 term_reason  Record_data  STATUS_YEAR
# termtype_desc
# Involuntary            4933         5024         5024
# Not Applicable            0            0            0
# Voluntary              4799         4981         4913

# %% [markdown]
# get the no of emp and average age in each dname

# %%
df.groupby('dname').agg({'ID':'count','age':'mean'})
# Out:
#                           ID        age
# dname
# Accounting                 6  65.000000
# Accounts Payable           4  63.750000
# Accounts Receiveable       5  63.000000
# Audit                      4  61.250000
# Bakery                   898  45.783964
# Compensation               4  61.250000
# Customer Service        1190  30.806723
# Dairy                   1033  39.882865
# Employee Records           6  63.333333
# Executive                 10  56.900000
# HR Technology              9  63.000000
# Information Technology     5  60.000000
# Investment                 4  61.250000
# Labor Relations            6  61.666667
# Legal                      3  61.666667
# Meats                   1252  57.503195
# Processed Foods          736  35.770380
# Produce                 1060  53.550000
# Recruitment                9  62.555556
# Store Management          35  61.971429
# Training                   5  62.000000

# %% [markdown]
# get the no of emp and average_age in each status_year,business_unit

# %%
df.groupby(['STATUS_YEAR','BUSINESS_UNIT']).agg({'ID':'count','age':'mean'})
# Out:
#                              ID        age
# STATUS_YEAR BUSINESS_UNIT
# 2006        Stores          134  60.000000
# 2007        Headoffice        1  57.000000
#             Stores          161  59.198758
# 2008        Stores          164  58.420732
# 2009        Headoffice       23  60.000000
#             Stores          119  59.109244
# 2010        Headoffice        9  60.000000
#             Stores          114  55.175439
# 2011        Stores          110  43.063636
# 2012        Stores          130  44.146154
# 2013        Stores          105  47.952381
# 2014        Headoffice       24  65.000000
#             Stores          229  37.864629
# 2015        Headoffice       23  60.956522
#             Stores         4938  42.844876

# %% [markdown]
# get the job in which more than 100 empoyees are present

# %%
g=df['job'].value_counts()
g[g>100]
# Out:
# job
# Meat Cutter      1218
# Cashier          1158
# Dairy Person     1032
# Produce Clerk    1027
# Baker             865
# Shelf Stocker     704
# Name: count, dtype: int64

# %% [markdown]
# get the statistical description for all numerical columns

# %%
n=df.corr(numeric_only=True)
n.describe()
# Out:
#              ID       age  experence  STATUS_YEAR
# count  4.000000  4.000000   4.000000     4.000000
# mean  -0.162277  0.141156   0.264592     0.255990
# std    0.949061  0.940143   0.879652     0.554351
# min   -0.946295 -0.946295  -0.928050    -0.338389
# 25%   -0.932612 -0.490365  -0.129179     0.018236
# 50%   -0.351407  0.255459   0.493210     0.181174
# 75%    0.418927  0.886981   0.886981     0.418927
# max    1.000000  1.000000   1.000000     1.000000

# %% [markdown]
# # Plots

# %% [markdown]
# UNIVARIANT PLOTS EXAMPLES QUESTION

# %%
df.columns
# Out:
# Index(['ID', 'DOB', 'age', 'Gender', 'hire_date', 'dname', 'job', 'city',
#        'experence', 'exp_level', 'BUSINESS_UNIT', 'status', 'term_date',
#        'termtype_desc', 'term_reason', 'Record_data', 'STATUS_YEAR'],
#       dtype='object')

# %% [markdown]
# Plot 1)How many emplyees are there in each status catogary

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=df,x='status')
plt.show()
plt.savefig(fname='plot1')

# %% [markdown]
# Observation:More active employees are present compared to terminated employees

# %% [markdown]
# Plot 2) How many active and terminated employees are there in each experience level

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='status',hue='exp_level')
plt.legend(loc='upper left',fontsize=7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation: Almost active and terminated employees are same but in mid senior and senior have more active employees

# %%
df.columns
# Out:
# Index(['ID', 'DOB', 'age', 'Gender', 'hire_date', 'dname', 'job', 'city',
#        'experence', 'exp_level', 'BUSINESS_UNIT', 'status', 'term_date',
#        'termtype_desc', 'term_reason', 'Record_data', 'STATUS_YEAR'],
#       dtype='object')

# %% [markdown]
# Plot 3) Draw a pie chart from the attrition data set the proportion of different termination types among employees

# %%
#Pie chart not present in seaborn

#for pie chart first step is  take value and index
val=df['termtype_desc'].value_counts().values
idx=df['termtype_desc'].value_counts().index
print(val)
print(idx)
# Out:
# [4799 1270  215]
# Index(['Not Applicable', 'Voluntary', 'Involuntary'], dtype='object', name='termtype_desc')

# %%
plt.figure(figsize=(6,3))
# plt.pie(x=val)
# plt.pie(x=val,labels=idx)
plt.pie(x=val,labels=idx,autopct='%.2f')
plt.title('Proportion of term_type')
plt.show()

# %% [markdown]
# Note: We use countplot and piechart for only catogorcal datas if there is is numbers we use KDE (used for continious data only(float))

# %% [markdown]
# Plot 4) Visualize the probablity density of employee ages usng KDE plot
#
# OR
#
# Plot the smooth curve to understand the how employees aged are distributed

# %%
plt.figure(figsize=(7,4))
sns.kdeplot(data=df,x='age')
plt.title('Age distribution')
plt.xticks(range(10,80,5))
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Plot 5) Create the histogram to visualize the distrbution of employees ages

# %%
plt.figure(figsize=(6,3))
plt.title('Age distribution')
sns.histplot(data=df,x='age')
plt.xticks(range(10,80,5))
plt.show()

# %% [markdown]
# BIVARIANT PLOT EXAMPLES QUESTIONS

# %% [markdown]
# Bivariant plot
# 1) Bar plot
# 2) Scatter plot
# 3) Line plot
# 4) Box plot

# %% [markdown]
# Plot 6)Show the average expiriance of employees for each gender

# %% [markdown]
# Note:Y axis always for numerical data

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df,y='experence',x='Gender')
plt.title('Average expiriance in each gender')
plt.show()

# %% [markdown]
# Plot 7) Show the maximum expiriance of employee for each gender and status

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df,x='Gender',estimator='max',y='experence',hue='status')
plt.title('Maximum expiriance in each gender and status')
plt.show()

# %% [markdown]
# Plot 8) Create the scatterplot to visualize the relationship between employee age and expiriance

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='age',y='experence')
plt.title('Relationship between age and expiriance')
plt.show()

# %% [markdown]
# Observation: Age and expiriance have positive and strong relation
#
# As age increases expiriance also increases

# %% [markdown]
# Plot 9)Create the scatterplot to visualize the relationship between employee age and expiriance for each status

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='experence',y='age',hue='status')
plt.title('Relationship between age and expiriance')
plt.show()

# %% [markdown]
# Observation:

# %% [markdown]
# Plot 10) Visualize the trend of employee experiance across different ages using line plot

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=df,x='age',y='experence')
plt.title('Trend of age vs experiance')
plt.show()

# %% [markdown]
# Observation:Here expiriance increses with age(few data points follow different pattern)

# %%
df.columns
# Out:
# Index(['ID', 'DOB', 'age', 'Gender', 'hire_date', 'dname', 'job', 'city',
#        'experence', 'exp_level', 'BUSINESS_UNIT', 'status', 'term_date',
#        'termtype_desc', 'term_reason', 'Record_data', 'STATUS_YEAR'],
#       dtype='object')

# %% [markdown]
# Plot 11) Use a box plot find outliers in age column

# %%
plt.figure(figsize=(9,4))
sns.boxplot(data=df,x='age')
plt.show()

# %% [markdown]
# Plot 12) Use a box plot find outliers in experiance column

# %%
plt.figure(figsize=(9,3))
sns.boxplot(data=df,x='experence')
plt.show()

# %% [markdown]
# Observaton: No outliers

# %% [markdown]
# Plot 13) Use a box plot find outliers in experiance column in each gender

# %%
plt.figure(figsize=(9,3))
sns.boxplot(data=df,x='experence',y='Gender')
plt.show()

# %% [markdown]
# Observation:No outliers

# %% [markdown]
# Plot 13) Use a box plot find outliers in experiance column in each gender and status

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df,x='experence',y='Gender',hue='status')
plt.show()

# %% [markdown]
# Observation: Terminated femalein the terminated female employees experiance

# %% [markdown]
# Multivariate plots

# %% [markdown]
# Plot 14) Use a heatmap to visualize the correlation between numerical columns in the dataset

# %%
c=df.corr(numeric_only=True).round(2)  #To do multivariate plot we have to take only numerical data
c
# Out:
#                ID   age  experence  STATUS_YEAR
# ID           1.00 -0.95      -0.93         0.23
# age         -0.95  1.00       0.85        -0.34
# experence   -0.93  0.85       1.00         0.14
# STATUS_YEAR  0.23 -0.34       0.14         1.00

# %%
sns.heatmap(c,annot=True,fmt='.3g')
# Out:
# <Axes: >

# %% [markdown]
# For my reference

# %%
d=df[['age','experence']].corr(numeric_only=True).round()

# %%
sns.heatmap(d)
# Out:
# <Axes: >

# %% [markdown]
# Observation:Age and experiance are having 85% of +ve strong relation.

# %% [markdown]
# Plot 15)Use a pairplot to visualize the correlation between numerical columns in the dataset

# %%
plt.figure(figsize=(6,4))
sns.pairplot(df)
plt.show()
